# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
path = '/content/drive/MyDrive/Project 1/Technology & Sustainability/AI Preparedness Index Dataset.csv'
df = pd.read_csv(path, encoding='latin-1')
df.head(1)
# Out:
#    ISO    Country  AI preparedness Index  GDP per capita (current US$)  \
# 0  AUS  Australia                   0.73                       64821.0
#
#    GDP per capita growth (annual %)  Real GDP growth (Annual change in %)  \
# 0                              0.94                                   2.0
#
#    Innovation and Economic Integration  Digitial Infrastructure  \
# 0                                 0.16                     0.18
#
#    Individuals using the Internet (% of population)  \
# 0                                              97.1
#
#    Secure Internet servers (per 1 million people)  Regulation and Ethics  \
# 0                                         47568.0                   0.21
#
#    Human Capital and Labor Market Policies
# 0                                     0.17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 12 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   ISO                                               174 non-null    object
#  1   Country                                           174 non-null    object
#  2   AI preparedness Index                             165 non-null    float64
#  3   GDP per capita (current US$)                      168 non-null    float64
#  4   GDP per capita growth (annual %)                  167 non-null    float64
#  5   Real GDP growth (Annual change in %)              170 non-null    float64
#  6   Innovation and Economic Integration               167 non-null    float64
#  7   Digitial Infrastructure                           173 non-null    float64
#  8   Individuals using the Internet (% of population)  162 non-null    float64
#  9   Secure Internet servers (per 1 million people)    173 non-null    float64
#  10  Regulation and Ethics                             174 non-null    float64
#  11  Human Capital and Labor Market Policies           173 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 16.4+ KB

# %%
df['ISO'].nunique()
# Out:
# 174

# %%
df.isnull().sum()
# Out:
# ISO                                                  0
# Country                                              0
# AI preparedness Index                                9
# GDP per capita (current US$)                         6
# GDP per capita growth (annual %)                     7
# Real GDP growth (Annual change in %)                 4
# Innovation and Economic Integration                  7
# Digitial Infrastructure                              1
# Individuals using the Internet (% of population)    12
# Secure Internet servers (per 1 million people)       1
# Regulation and Ethics                                0
# Human Capital and Labor Market Policies              1
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      ISO                   Country  AI preparedness Index  \
# 23   MAC                     Macao                    NaN
# 29   PRI               Puerto Rico                    NaN
# 36   TWN             Taiwan, China                    NaN
# 72   IND                     India                   0.49
# 80   LBN                   Lebanon                   0.42
# 83   MDV                  Maldives                    NaN
# 109  SYR      Syrian Arab Republic                   0.30
# 117  VEN                 Venezuela                   0.27
# 118  AFG               Afghanistan                    NaN
# 121  BTN                    Bhutan                   0.44
# 126  CAF  Central African Republic                   0.18
# 133  ETH                  Ethiopia                   0.25
# 138  HTI                     Haiti                   0.27
# 158  STP     Sao Tome and Principe                    NaN
# 161  SOM                   Somalia                    NaN
# 162  SSD               South Sudan                    NaN
# 163  SDN                     Sudan                   0.23
# 169  UZB                Uzbekistan                    NaN
# 171  YEM                     Yemen                   0.25
#
#      GDP per capita (current US$)  GDP per capita growth (annual %)  \
# 23                        67477.0                             74.67
# 29                        36779.0                              1.02
# 36                            NaN                               NaN
# 72                         2481.0                              7.20
# 80                            NaN                               NaN
# 83                        12530.0                              4.35
# 109                           NaN                               NaN
# 117                           NaN                               NaN
# 118                         416.0                              0.54
# 121                           NaN                               NaN
# 126                         496.0                             -0.19
# 133                        1272.0                              3.76
# 138                        1706.0                             -2.99
# 158                        2941.0                             -1.61
# 161                         597.0                              1.06
# 162                           NaN                               NaN
# 163                        2183.0                            -21.16
# 169                        2850.0                              4.16
# 171                         477.0                               NaN
#
#      Real GDP growth (Annual change in %)  \
# 23                                    NaN
# 29                                    0.6
# 36                                    NaN
# 72                                    8.2
# 80                                   -0.7
# 83                                    4.0
# 109                                   NaN
# 117                                   4.0
# 118                                   2.7
# 121                                   5.0
# 126                                   0.7
# 133                                   7.2
# 138                                  -1.9
# 158                                   0.4
# 161                                   4.2
# 162                                   NaN
# 163                                 -18.3
# 169                                   6.3
# 171                                  -2.0
#
#      Innovation and Economic Integration  Digitial Infrastructure  \
# 23                                   NaN                     0.16
# 29                                   NaN                     0.08
# 36                                  0.13                      NaN
# 72                                  0.11                     0.11
# 80                                  0.13                     0.09
# 83                                   NaN                     0.10
# 109                                 0.08                     0.07
# 117                                 0.07                     0.07
# 118                                  NaN                     0.05
# 121                                 0.09                     0.09
# 126                                 0.09                     0.02
# 133                                 0.07                     0.05
# 138                                 0.14                     0.03
# 158                                  NaN                     0.06
# 161                                 0.12                     0.04
# 162                                  NaN                     0.02
# 163                                 0.08                     0.05
# 169                                  NaN                     0.11
# 171                                 0.12                     0.04
#
#      Individuals using the Internet (% of population)  \
# 23                                               89.2
# 29                                                NaN
# 36                                                NaN
# 72                                                NaN
# 80                                               83.5
# 83                                               84.7
# 109                                               NaN
# 117                                               NaN
# 118                                              17.7
# 121                                              88.4
# 126                                               NaN
# 133                                               NaN
# 138                                               NaN
# 158                                              61.5
# 161                                               NaN
# 162                                               NaN
# 163                                               NaN
# 169                                              89.0
# 171                                               NaN
#
#      Secure Internet servers (per 1 million people)  Regulation and Ethics  \
# 23                                           5760.0                   0.14
# 29                                            464.0                   0.14
# 36                                              NaN                   0.18
# 72                                            966.0                   0.15
# 80                                            676.0                   0.08
# 83                                           1238.0                   0.11
# 109                                            93.0                   0.02
# 117                                           223.0                   0.02
# 118                                            44.0                   0.04
# 121                                          1227.0                   0.15
# 126                                             3.0                   0.04
# 133                                            17.0                   0.07
# 138                                             7.0                   0.04
# 158                                            39.0                   0.09
# 161                                            10.0                   0.03
# 162                                             4.0                   0.01
# 163                                             2.0                   0.03
# 169                                           824.0                   0.10
# 171                                             7.0                   0.02
#
#      Human Capital and Labor Market Policies
# 23                                      0.09
# 29                                      0.14
# 36                                      0.20
# 72                                      0.12
# 80                                      0.12
# 83                                      0.08
# 109                                     0.13
# 117                                     0.11
# 118                                     0.05
# 121                                     0.12
# 126                                     0.03
# 133                                     0.06
# 138                                     0.06
# 158                                     0.07
# 161                                      NaN
# 162                                     0.04
# 163                                     0.07
# 169                                     0.13
# 171                                     0.07

# %%
df.loc[72,'Individuals using the Internet (% of population)'] = 51.5

# %%
df.dropna(inplace=True)

# %%
df[df['Country'] == 'India']
# Out:
#     ISO Country  AI preparedness Index  GDP per capita (current US$)  \
# 72  IND   India                   0.49                        2481.0
#
#     GDP per capita growth (annual %)  Real GDP growth (Annual change in %)  \
# 72                               7.2                                   8.2
#
#     Innovation and Economic Integration  Digitial Infrastructure  \
# 72                                 0.11                     0.11
#
#     Individuals using the Internet (% of population)  \
# 72                                              51.5
#
#     Secure Internet servers (per 1 million people)  Regulation and Ethics  \
# 72                                           966.0                   0.15
#
#     Human Capital and Labor Market Policies
# 72                                     0.12

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
################################################################################################################################################################################

# %%
df.head(1)
# Out:
#    ISO    Country  AI preparedness Index  GDP per capita (current US$)  \
# 0  AUS  Australia                   0.73                       64821.0
#
#    GDP per capita growth (annual %)  Real GDP growth (Annual change in %)  \
# 0                              0.94                                   2.0
#
#    Innovation and Economic Integration  Digitial Infrastructure  \
# 0                                 0.16                     0.18
#
#    Individuals using the Internet (% of population)  \
# 0                                              97.1
#
#    Secure Internet servers (per 1 million people)  Regulation and Ethics  \
# 0                                         47568.0                   0.21
#
#    Human Capital and Labor Market Policies
# 0                                     0.17

# %% [markdown]
# # **Use following tables to see top 5 and bottom 5 AIPI**

# %%
# Sort the countries by AI Preparedness Index (descending for top, ascending for bottom)
top_5_countries = df.sort_values(by='AI preparedness Index', ascending=False).head(5)

# Display the results
print("Top 5 Countries by AI Preparedness Index:")
top_5_countries[['Country', 'AI preparedness Index']].reset_index(drop=True)
## India's rank is 72 and China's rank is 30 and Russia's rank is 45
# Out:
# Top 5 Countries by AI Preparedness Index:
#          Country  AI preparedness Index
# 0      Singapore                   0.80
# 1        Denmark                   0.78
# 2  United States                   0.77
# 3    Netherlands                   0.77
# 4        Finland                   0.76

# %%
bottom_5_countries = df.sort_values(by='AI preparedness Index', ascending=True).head(5)
print("\nBottom 5 Countries by AI Preparedness Index:")
bottom_5_countries[['Country', 'AI preparedness Index']].reset_index(drop=True)
# Out:
# Bottom 5 Countries by AI Preparedness Index:
#       Country  AI preparedness Index
# 0        Chad                   0.23
# 1  Mauritania                   0.23
# 2       Libya                   0.24
# 3       Congo                   0.25
# 4     Comoros                   0.25

# %%
# Sort the countries by AI GDP per capita (current US$)(descending for top, ascending for bottom)
top_5_countries_gdp = df.sort_values(by='GDP per capita (current US$)', ascending=False).head(5)

# Display the results
print("Top 5 Countries by GDP per capita:")
top_5_countries_gdp[['Country', 'GDP per capita (current US$)']].reset_index(drop=True)
# Out:
# Top 5 Countries by GDP per capita:
#        Country  GDP per capita (current US$)
# 0   Luxembourg                      128678.0
# 1      Ireland                      103888.0
# 2  Switzerland                       99565.0
# 3       Norway                       87925.0
# 4    Singapore                       84734.0

# %%
# Select only the relevant columns for correlation
correlation_columns = [
    'AI preparedness Index',
    'GDP per capita (current US$)',
    'GDP per capita growth (annual %)',
    'Innovation and Economic Integration',
    'Digitial Infrastructure',
    'Regulation and Ethics',
    'Human Capital and Labor Market Policies'
]

# Create a smaller dataframe with only these columns
corr_df = df[correlation_columns]

# Calculate the correlation matrix
correlation_matrix = corr_df.corr()

# Display the correlations of 'AI preparedness Index' with others
ai_corr = correlation_matrix['AI preparedness Index'].drop('AI preparedness Index')

print("Correlation of AI Preparedness Index with other variables:")
ai_corr
# Out:
# Correlation of AI Preparedness Index with other variables:
# GDP per capita (current US$)               0.793299
# GDP per capita growth (annual %)          -0.187207
# Innovation and Economic Integration        0.884116
# Digitial Infrastructure                    0.961397
# Regulation and Ethics                      0.947293
# Human Capital and Labor Market Policies    0.911467
# Name: AI preparedness Index, dtype: float64

# %%
# Plot a heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # **AIPI vs GDP**

# %%
AIPI_GDP_Corr = df['AI preparedness Index'].corr(df['GDP per capita (current US$)'])
AIPI_GDP_Corr
# Out:
# np.float64(0.7932988390387568)

# %%
# Scatter plot with regression line
plt.figure(figsize=(8,6))
sns.regplot(
    data=df,
    x='GDP per capita (current US$)',
    y='AI preparedness Index',
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('AI Preparedness Index vs GDP per Capita', fontsize=14)
plt.xlabel('GDP per Capita (current US$)', fontsize=12)
plt.ylabel('AI Preparedness Index', fontsize=12)
plt.grid(True)
plt.show()

# Calculate and print correlation
correlation = df['AI preparedness Index'].corr(df['GDP per capita (current US$)'])
print(f"Correlation between AI Preparedness Index and GDP per Capita: {correlation:.2f}")
# Out:
# Correlation between AI Preparedness Index and GDP per Capita: 0.79

# %%
# Top 10 countries by AI Preparedness Index
top_10_countries = df.sort_values(by='AI preparedness Index', ascending=False).head(10)
top_10_countries = top_10_countries.rename(columns={'Country':'Country_AIPI', 'AI preparedness Index':'AIPI'})
top_10_countries = top_10_countries[['Country_AIPI', 'AIPI']].reset_index(drop=True)

# Top 10 countries by GDP per capita
top_10_countries_GDP = df.sort_values(by='GDP per capita (current US$)', ascending=False).head(10)
top_10_countries_GDP = top_10_countries_GDP.rename(columns={'Country':'Country_GDP', 'GDP per capita (current US$)':'GDP'})
top_10_countries_GDP = top_10_countries_GDP[['Country_GDP', 'GDP']].reset_index(drop=True)

# Combine both tables side by side
combined_table = pd.concat([top_10_countries, top_10_countries_GDP], axis=1)

# Display the final combined table
print("Top 10 Countries by AI Preparedness Index and GDP per Capita:")
combined_table
# Out:
# Top 10 Countries by AI Preparedness Index and GDP per Capita:
#     Country_AIPI  AIPI    Country_GDP       GDP
# 0      Singapore  0.80     Luxembourg  128678.0
# 1        Denmark  0.78        Ireland  103888.0
# 2  United States  0.77    Switzerland   99565.0
# 3    Netherlands  0.77         Norway   87925.0
# 4        Finland  0.76      Singapore   84734.0
# 5    Switzerland  0.76  United States   82769.0
# 6        Estonia  0.76          Qatar   80196.0
# 7    New Zealand  0.75        Iceland   79637.0
# 8         Sweden  0.75        Denmark   68454.0
# 9        Germany  0.75      Australia   64821.0

# %% [markdown]
# # **AIPI vs GDP per capita growth**

# %%
AIPI_GDP_Growth_Corr = df['AI preparedness Index'].corr(df['GDP per capita growth (annual %)'])
AIPI_GDP_Growth_Corr
# approx -0.19
# Out:
# np.float64(-0.18720730916421943)

# %%
# Scatter plot with regression line
plt.figure(figsize=(8,6))
sns.regplot(
    data=df,
    x='GDP per capita growth (annual %)',
    y='AI preparedness Index',
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('GDP per Capita Growth vs AI Preparedness Index', fontsize=14)
plt.xlabel('GDP per capita growth (annual %)', fontsize=12)
plt.ylabel('AI preparedness Index', fontsize=12)
plt.grid(True)
plt.show()

# Calculate and print correlation
correlation = df['AI preparedness Index'].corr(df['GDP per capita growth (annual %)'])
print(f"Correlation between AI Preparedness Index and GDP per Capita Growth: {correlation:.2f}")
# Out:
# Correlation between AI Preparedness Index and GDP per Capita Growth: -0.19

# %% [markdown]
# # **APIP vs Digitial Infrastructure**

# %%
df.head(1)
# Out:
#    ISO    Country  AI preparedness Index  GDP per capita (current US$)  \
# 0  AUS  Australia                   0.73                       64821.0
#
#    GDP per capita growth (annual %)  Real GDP growth (Annual change in %)  \
# 0                              0.94                                   2.0
#
#    Innovation and Economic Integration  Digitial Infrastructure  \
# 0                                 0.16                     0.18
#
#    Individuals using the Internet (% of population)  \
# 0                                              97.1
#
#    Secure Internet servers (per 1 million people)  Regulation and Ethics  \
# 0                                         47568.0                   0.21
#
#    Human Capital and Labor Market Policies
# 0                                     0.17

# %%
AIPI_Digi_inter_Corr = df['AI preparedness Index'].corr(df['Secure Internet servers (per 1 million people)'])
AIPI_Digi_inter_Corr
# Out:
# np.float64(0.46607456678538406)

# %%
AIPI_Digi_infra_Corr = df['AI preparedness Index'].corr(df['Digitial Infrastructure'])
AIPI_Digi_infra_Corr
# Out:
# np.float64(0.9613970667148305)

# %%
# Scatter plot with regression line
plt.figure(figsize=(8,6))
sns.regplot(
    data=df,
    x='Digitial Infrastructure',
    y='AI preparedness Index',
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('Digital Infrastructure vs AI Preparedness Index', fontsize=14)
plt.xlabel('Digital Infrastructure', fontsize=12)
plt.ylabel('AI preparedness Index', fontsize=12)
plt.grid(True)
plt.show()

# Calculate and print correlation
correlation = df['AI preparedness Index'].corr(df['Digitial Infrastructure'])
print(f"Correlation between AI Preparedness Index and Digital Infrastructure: {correlation:.2f}")
# Out:
# Correlation between AI Preparedness Index and Digital Infrastructure: 0.96

# %%
# Top 10 countries by AI Preparedness Index
top_10_countries = df.sort_values(by='AI preparedness Index', ascending=False).head(10)
top_10_countries = top_10_countries.rename(columns={'Country':'Country_AIPI', 'AI preparedness Index':'AIPI'})
top_10_countries = top_10_countries[['Country_AIPI', 'AIPI']].reset_index(drop=True)

# Top 10 countries by Digitial Infrastructure
top_10_countries_Digi = df.sort_values(by='Digitial Infrastructure', ascending=False).head(10)
top_10_countries_Digi = top_10_countries_Digi.rename(columns={'Country':'Country_Digi', 'Digitial Infrastructure':'Digi'})
top_10_countries_Digi = top_10_countries_Digi[['Country_Digi', 'Digi']].reset_index(drop=True)

# Combine both tables side by side
combined_table1 = pd.concat([top_10_countries, top_10_countries_Digi], axis=1)

# Display the final combined table
print("Top 10 Countries by AI Preparedness Index and Digitial Infrastructure:")
combined_table1
# Out:
# Top 10 Countries by AI Preparedness Index and Digitial Infrastructure:
#     Country_AIPI  AIPI   Country_Digi  Digi
# 0      Singapore  0.80      Singapore  0.21
# 1        Denmark  0.78        Estonia  0.20
# 2  United States  0.77      Hong Kong  0.20
# 3    Netherlands  0.77        Denmark  0.20
# 4        Finland  0.76        Germany  0.19
# 5    Switzerland  0.76    Netherlands  0.19
# 6        Estonia  0.76    New Zealand  0.19
# 7    New Zealand  0.75        Finland  0.19
# 8         Sweden  0.75     Luxembourg  0.19
# 9        Germany  0.75  United States  0.19

# %% [markdown]
# # **AIPI vs Regulation and Ethics**

# %%
AIPI_Regulations_Corr = df['AI preparedness Index'].corr(df['Regulation and Ethics'])
AIPI_Regulations_Corr
# Out:
# np.float64(0.9472932081074789)

# %%
# Scatter plot with regression line
plt.figure(figsize=(8,6))
sns.regplot(
    data=df,
    x='Regulation and Ethics',
    y='AI preparedness Index',
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('Regulation and Ethics vs AI Preparedness Index', fontsize=14)
plt.xlabel('Regulation and Ethics', fontsize=12)
plt.ylabel('AI preparedness Index', fontsize=12)
plt.grid(True)
plt.show()

# Calculate and print correlation
correlation = df['AI preparedness Index'].corr(df['Regulation and Ethics'])
print(f"Correlation between AI Preparedness Index and Regulation and Ethics: {correlation:.2f}")
# Out:
# Correlation between AI Preparedness Index and Regulation and Ethics: 0.95

# %%
# Top 10 countries by AI Preparedness Index
top_10_countries = df.sort_values(by='AI preparedness Index', ascending=False).head(10)
top_10_countries = top_10_countries.rename(columns={'Country':'Country_AIPI', 'AI preparedness Index':'AIPI'})
top_10_countries = top_10_countries[['Country_AIPI', 'AIPI']].reset_index(drop=True)

# Top 10 countries by Regulation and Ethics
top_10_countries_Regulations = df.sort_values(by='Regulation and Ethics', ascending=False).head(10)
top_10_countries_Regulations = top_10_countries_Regulations.rename(columns={'Country':'Country_Regulations', 'Regulation and Ethics':'Regulations_Ethics'})
top_10_countries_Regulations = top_10_countries_Regulations[['Country_Regulations', 'Regulations_Ethics']].reset_index(drop=True)

# Combine both tables side by side
combined_table2 = pd.concat([top_10_countries, top_10_countries_Regulations], axis=1)

# Display the final combined table
print("Top 10 Countries by AI Preparedness Index and Regulation and Ethics:")
combined_table2
# Out:
# Top 10 Countries by AI Preparedness Index and Regulation and Ethics:
#     Country_AIPI  AIPI Country_Regulations  Regulations_Ethics
# 0      Singapore  0.80             Finland                0.23
# 1        Denmark  0.78             Denmark                0.22
# 2  United States  0.77             Estonia                0.22
# 3    Netherlands  0.77         Netherlands                0.22
# 4        Finland  0.76         New Zealand                0.22
# 5    Switzerland  0.76          Luxembourg                0.22
# 6        Estonia  0.76       United States                0.22
# 7    New Zealand  0.75           Singapore                0.22
# 8         Sweden  0.75             Iceland                0.21
# 9        Germany  0.75           Australia                0.21

# %% [markdown]
# # **AIPI vs Human Capital and Labor Market Policies**

# %%
AIPI_HR_Corr = df['AI preparedness Index'].corr(df['Human Capital and Labor Market Policies'])
AIPI_HR_Corr
# Out:
# np.float64(0.9114667710466624)

# %%
# Scatter plot with regression line
plt.figure(figsize=(8,6))
sns.regplot(
    data=df,
    x='Human Capital and Labor Market Policies',
    y='AI preparedness Index',
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('Human Capital and Labor Market Policies vs AI Preparedness Index', fontsize=14)
plt.xlabel('Human Capital and Labor Market Policies', fontsize=12)
plt.ylabel('AI preparedness Index', fontsize=12)
plt.grid(True)
plt.show()

# Calculate and print correlation
correlation = df['AI preparedness Index'].corr(df['Human Capital and Labor Market Policies'])
print(f"Correlation between AI Preparedness Index and Human Capital and Labor Market Policies: {correlation:.2f}")
# Out:
# Correlation between AI Preparedness Index and Human Capital and Labor Market Policies: 0.91

# %%
# Top 10 countries by AI Preparedness Index
top_10_countries = df.sort_values(by='AI preparedness Index', ascending=False).head(10)
top_10_countries = top_10_countries.rename(columns={'Country':'Country_AIPI', 'AI preparedness Index':'AIPI'})
top_10_countries = top_10_countries[['Country_AIPI', 'AIPI']].reset_index(drop=True)

# Top 10 countries by Human Capital and Labor Market Policies
top_10_countries_HC_LMP = df.sort_values(by='Human Capital and Labor Market Policies', ascending=False).head(10)
top_10_countries_HC_LMP = top_10_countries_HC_LMP.rename(columns={'Country':'Country_HC_LMP', 'Human Capital and Labor Market Policies':'HC_LMP'})
top_10_countries_HC_LMP = top_10_countries_HC_LMP[['Country_HC_LMP', 'HC_LMP']].reset_index(drop=True)

# Combine both tables side by side
combined_table3 = pd.concat([top_10_countries, top_10_countries_HC_LMP], axis=1)

# Display the final combined table
print("Top 10 Countries by AI Preparedness Index and Human Capital and Labor Market Policies:")
combined_table3
# Out:
# Top 10 Countries by AI Preparedness Index and Human Capital and Labor Market Policies:
#     Country_AIPI  AIPI Country_HC_LMP  HC_LMP
# 0      Singapore  0.80      Singapore    0.20
# 1        Denmark  0.78    Switzerland    0.19
# 2  United States  0.77        Estonia    0.18
# 3    Netherlands  0.77        Germany    0.18
# 4        Finland  0.76   Saudi Arabia    0.18
# 5    Switzerland  0.76  United States    0.18
# 6        Estonia  0.76        Denmark    0.18
# 7    New Zealand  0.75    New Zealand    0.18
# 8         Sweden  0.75         Canada    0.17
# 9        Germany  0.75        Finland    0.17

# %% [markdown]
# # **AIPI vs Innovation and Economic Integration**

# %%
df.head(1)
# Out:
#    ISO    Country  AI preparedness Index  GDP per capita (current US$)  \
# 0  AUS  Australia                   0.73                       64821.0
#
#    GDP per capita growth (annual %)  Real GDP growth (Annual change in %)  \
# 0                              0.94                                   2.0
#
#    Innovation and Economic Integration  Digitial Infrastructure  \
# 0                                 0.16                     0.18
#
#    Individuals using the Internet (% of population)  \
# 0                                              97.1
#
#    Secure Internet servers (per 1 million people)  Regulation and Ethics  \
# 0                                         47568.0                   0.21
#
#    Human Capital and Labor Market Policies
# 0                                     0.17

# %%
AIPI_Innov_Corr = df['AI preparedness Index'].corr(df['Innovation and Economic Integration'])
AIPI_Innov_Corr
# Out:
# np.float64(0.8841162529415163)

# %%
# Scatter plot with regression line
plt.figure(figsize=(8,6))
sns.regplot(
    data=df,
    x='Innovation and Economic Integration',
    y='AI preparedness Index',
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)

plt.title('Innovation & Economic Integration vs AI Preparedness Index', fontsize=14)
plt.xlabel('Innovation and Economic Integration', fontsize=12)
plt.ylabel('AI preparedness Index', fontsize=12)
plt.grid(True)
plt.show()

# Calculate and print correlation
correlation = df['AI preparedness Index'].corr(df['Innovation and Economic Integration'])
print(f"Correlation between AI Preparedness Index and Innovation & Economic Integration: {correlation:.2f}")
# Out:
# Correlation between AI Preparedness Index and Innovation & Economic Integration: 0.88

# %% [markdown]
# # **Corr between GDP and other parameters except AIPI**

# %%
df.head(1)
# Out:
#    ISO    Country  AI preparedness Index  GDP per capita (current US$)  \
# 0  AUS  Australia                   0.73                       64821.0
#
#    GDP per capita growth (annual %)  Real GDP growth (Annual change in %)  \
# 0                              0.94                                   2.0
#
#    Innovation and Economic Integration  Digitial Infrastructure  \
# 0                                 0.16                     0.18
#
#    Individuals using the Internet (% of population)  \
# 0                                              97.1
#
#    Secure Internet servers (per 1 million people)  Regulation and Ethics  \
# 0                                         47568.0                   0.21
#
#    Human Capital and Labor Market Policies
# 0                                     0.17

# %%
# Select only the relevant columns for correlation
correlation_columnss = [
    'GDP per capita (current US$)',
    'Innovation and Economic Integration',
    'Digitial Infrastructure',
    'Regulation and Ethics',
    'Human Capital and Labor Market Policies'
]

# Create a smaller dataframe with only these columns
corr_dff = df[correlation_columnss]

# Calculate the correlation matrix
correlation_matrixx = corr_dff.corr()

# Display the correlations of 'GDP per capita (current US$)' with others
gdp_corr = correlation_matrixx['GDP per capita (current US$)'].drop('GDP per capita (current US$)')

print("Correlation of GDP per capita (current US$) with other variables except AIPI:")
gdp_corr
# Out:
# Correlation of GDP per capita (current US$) with other variables except AIPI:
# Innovation and Economic Integration        0.709343
# Digitial Infrastructure                    0.742436
# Regulation and Ethics                      0.773882
# Human Capital and Labor Market Policies    0.712459
# Name: GDP per capita (current US$), dtype: float64
