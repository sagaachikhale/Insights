# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
path1 = '/content/drive/MyDrive/Project 2/Aerospace/complexity_planning_time_data.csv'
df1 = pd.read_csv(path1)
df1 #complexity_planning_time_data
#Shows how mission planning time varies across complexity levels (Low to Critical) for both Traditional and AI approaches.
# Out:
#   Complexity  Traditional  AI-Augmented
# 0        Low         12.3           9.6
# 1     Medium         22.7          15.2
# 2       High         31.5          18.9
# 3   Critical         43.1          25.5

# %%
df1 = df1.rename(columns={'Complexity':'complexity'})
df1
# Out:
#   complexity  Traditional  AI-Augmented
# 0        Low         12.3           9.6
# 1     Medium         22.7          15.2
# 2       High         31.5          18.9
# 3   Critical         43.1          25.5

# %%
path2 = '/content/drive/MyDrive/Project 2/Aerospace/expert_evaluation_data.csv'
df2 = pd.read_csv(path2)
df2.head() #expert_evaluation_data
#Experts from different roles and agencies rate traditional vs AI planning. Includes years of experience and perceived improvement.
# Out:
#   expert_id                          role agency   experience  \
# 0       E01              Mission Director   NASA   5-10 years
# 1       E02       Flight Dynamics Officer    ESA  10-15 years
# 2       E03              Mission Director    ESA   5-10 years
# 3       E04  Resource Planning Specialist   JAXA    15+ years
# 4       E05       Flight Dynamics Officer   JAXA   5-10 years
#
#    traditional_rating  ai_rating  perceived_improvement_pct
# 0            7.608453   7.990069                   5.015689
# 1            8.165361   8.576331                   5.033095
# 2            7.235882   7.668645                   5.980795
# 3            7.440638   7.924737                   6.506151
# 4            7.786730   8.358370                   7.341199

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   expert_id                  28 non-null     object
#  1   role                       28 non-null     object
#  2   agency                     28 non-null     object
#  3   experience                 28 non-null     object
#  4   traditional_rating         28 non-null     float64
#  5   ai_rating                  28 non-null     float64
#  6   perceived_improvement_pct  28 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 1.7+ KB

# %%
## df2['perceived_improvement_pct'].value_counts()
# expert_id = 28 unique values
# role = Resource Planning Specialist(8); Flight Dynamics Officer(7); Mission Director(6);Science Operations Planner(4); Risk Assessment Engineer(3)
# agency = NASA(11); ESA(10); JAXA(7)
# experience = 10-15 years(12); 5-10 years(8); 15+ years(8)
# traditional_rating = assuming out of 10
# ai_rating = assuming out of 10
# perceived_improvement_pct = percentage of improvement of ai method than traditional

# %%
path3 = '/content/drive/MyDrive/Project 2/Aerospace/knowledge_transfer_data.csv'
df3 = pd.read_csv(path3)
df3 #knowledge_transfer_data
# Compares how well knowledge is transferred across mission sequences with each method.
# Out:
#    Mission_Sequence  Traditional  AI-Augmented
# 0                 1         59.3          83.6
# 1                 2         61.2          85.1
# 2                 3         63.5          89.3
# 3                 4         64.1          90.7
# 4                 5         65.7          92.2

# %%
df3.rename(columns={'Mission_Sequence':'mission_sequence'}, inplace=True)
df3
# Out:
#    mission_sequence  Traditional  AI-Augmented
# 0                 1         59.3          83.6
# 1                 2         61.2          85.1
# 2                 3         63.5          89.3
# 3                 4         64.1          90.7
# 4                 5         65.7          92.2

# %%
path4 = '/content/drive/MyDrive/Project 2/Aerospace/mission_phase_data.csv'
df4 = pd.read_csv(path4)
df4.head(2) #mission_phase_data
#Time spent planning different phases (Launch, Orbital, etc.) and the contingency coverage achieved.
# Out:
#   mission_id   phase planning_method  planning_time_hours  \
# 0       M001  Launch     Traditional            12.859352
# 1       M001  Launch    AI-Augmented             8.210370
#
#    contingency_coverage_pct
# 0                 77.659540
# 1                 93.772477

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   mission_id                418 non-null    object
#  1   phase                     418 non-null    object
#  2   planning_method           418 non-null    object
#  3   planning_time_hours       418 non-null    float64
#  4   contingency_coverage_pct  418 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 16.5+ KB

# %%
# df4['contingency_coverage_pct'].value_counts()
# mission_id = from M001 to M047
# phase = Launch(94); Transit(94); Orbital(94); Return(94); Surface(42)
# planning_method = Traditional(209); AI-Augmented(209)
# planning_time_hours = Time in hours
# contingency_coverage_pct = assuming out of 100

# %%
path5 = '/content/drive/MyDrive/Project 2/Aerospace/missions_data.csv'
df5 = pd.read_csv(path5)
df5.head(2) #missions_data
# Contains details of individual missions: agency, type, complexity, duration, and date.
# Out:
#   mission_id        date  mission_type agency complexity  duration_days
# 0       M001  2023-10-27    Deep Space   NASA        Low            120
# 1       M002  2018-11-13  ISS Resupply   NASA        Low             12

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mission_id     47 non-null     object
#  1   date           47 non-null     object
#  2   mission_type   47 non-null     object
#  3   agency         47 non-null     object
#  4   complexity     47 non-null     object
#  5   duration_days  47 non-null     int64
# dtypes: int64(1), object(5)
# memory usage: 2.3+ KB

# %%
#df5['duration_days'].value_counts()
# mission_id = from M001 to M047
# date = 6 August 2015 - 31 December 2023
# mission_type = ISS Resupply(11); Lunar(11); Mars(10); Deep Space(8); Earth Orbit(7)
# agency = NASA(16); ESA(16); JAXA(15)
# complexity = Low(12), Medium(12), High(12), Critical(11)
# duration_days = from 12 days to 450 days

# %%
path6 = '/content/drive/MyDrive/Project 2/Aerospace/phase_contingency_data.csv'
df6 = pd.read_csv(path6)
df6 #phase_contingency_data
# Summarizes contingency coverage by phase using each planning method.
# Out:
#      Phase  Traditional  AI-Augmented
# 0   Launch         83.5          92.7
# 1  Transit         76.2          89.5
# 2  Orbital         72.8          91.2
# 3  Surface         68.7          88.9
# 4   Return         70.3          90.7

# %%
df6.rename(columns={'Phase':'phase'}, inplace=True)
df6
# Out:
#      phase  Traditional  AI-Augmented
# 0   Launch         83.5          92.7
# 1  Transit         76.2          89.5
# 2  Orbital         72.8          91.2
# 3  Surface         68.7          88.9
# 4   Return         70.3          90.7

# %%
path7 = '/content/drive/MyDrive/Project 2/Aerospace/planning_performance_data.csv'
df7 = pd.read_csv(path7)
df7.head(2) #planning_performance_data
# A detailed breakdown of performance metrics: planning time, contingency, resource use, adaptability, quality, etc., for each mission.
# Out:
#   mission_id planning_method  planning_time_hours  contingency_coverage_pct  \
# 0       M001     Traditional            14.454010                 76.100519
# 1       M001    AI-Augmented             8.677431                 92.875348
#
#    resource_efficiency_pct  knowledge_transfer_pct  adaptability_score  \
# 0                81.279352               62.271078            7.818015
# 1                87.647444               86.763941            9.419102
#
#    quality_assessment        date mission_type agency complexity  \
# 0            8.160731  2023-10-27   Deep Space   NASA        Low
# 1            8.651423  2023-10-27   Deep Space   NASA        Low
#
#    duration_days
# 0            120
# 1            120

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   mission_id                94 non-null     object
#  1   planning_method           94 non-null     object
#  2   planning_time_hours       94 non-null     float64
#  3   contingency_coverage_pct  94 non-null     float64
#  4   resource_efficiency_pct   94 non-null     float64
#  5   knowledge_transfer_pct    94 non-null     float64
#  6   adaptability_score        94 non-null     float64
#  7   quality_assessment        94 non-null     float64
#  8   date                      94 non-null     object
#  9   mission_type              94 non-null     object
#  10  agency                    94 non-null     object
#  11  complexity                94 non-null     object
#  12  duration_days             94 non-null     int64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 9.7+ KB

# %%
path8 = '/content/drive/MyDrive/Project 2/Aerospace/resource_allocation_data.csv'
df8 = pd.read_csv(path8)
df8.head(2) #resource_allocation_data
# Measures how efficiently different resources (power, crew time, etc.) were used under each planning method.
# Out:
#   mission_id resource planning_method  efficiency_pct
# 0       M001    Power     Traditional       82.442038
# 1       M001    Power    AI-Augmented       88.380208

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mission_id       376 non-null    object
#  1   resource         376 non-null    object
#  2   planning_method  376 non-null    object
#  3   efficiency_pct   376 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 11.9+ KB

# %%
# df8['resource'].value_counts()
# resource = Power(94); Propellant(94); Bandwidth(94); Crew Time(94)

# %%
path9 = '/content/drive/MyDrive/Project 2/Aerospace/resource_optimization_data.csv'
df9 = pd.read_csv(path9)
df9 #resource_optimization_data
# Summarizes resource efficiency (Traditional vs AI) by resource type.
# Out:
#      Resource  Traditional  AI-Augmented
# 0       Power         83.2          89.1
# 1  Propellant         79.5          87.3
# 2   Bandwidth         84.6          86.2
# 3   Crew Time         79.4          90.3

# %%
df9.rename(columns={'Resource':'resource'}, inplace=True)
df9
# Out:
#      resource  Traditional  AI-Augmented
# 0       Power         83.2          89.1
# 1  Propellant         79.5          87.3
# 2   Bandwidth         84.6          86.2
# 3   Crew Time         79.4          90.3

# %%
path10 = '/content/drive/MyDrive/Project 2/Aerospace/simulation_scenario_data.csv'
df10 = pd.read_csv(path10)
df10.head(2) #simulation_scenario_data
#Tests both planning methods in different simulated conditions (e.g., system failure, communication loss), comparing improvements in time, contingency, and resource use.
# Out:
#   scenario_id       scenario_type complexity  trad_planning_time  \
# 0         S01  Communication Loss   Critical           26.232028
# 1         S02      System Anomaly       High           28.734588
#
#    trad_contingency_coverage  trad_resource_efficiency  ai_planning_time  \
# 0                  65.784890                 80.619928         16.192927
# 1                  71.684077                 80.483206         17.424637
#
#    ai_contingency_coverage  ai_resource_efficiency  time_improvement_pct  \
# 0                79.771257               87.507866             38.270398
# 1                88.550296               86.750349             39.360059
#
#    contingency_improvement_pct  resource_improvement_pct
# 0                    21.260758                  8.543715
# 1                    23.528542                  7.786896

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   scenario_id                  12 non-null     object
#  1   scenario_type                12 non-null     object
#  2   complexity                   12 non-null     object
#  3   trad_planning_time           12 non-null     float64
#  4   trad_contingency_coverage    12 non-null     float64
#  5   trad_resource_efficiency     12 non-null     float64
#  6   ai_planning_time             12 non-null     float64
#  7   ai_contingency_coverage      12 non-null     float64
#  8   ai_resource_efficiency       12 non-null     float64
#  9   time_improvement_pct         12 non-null     float64
#  10  contingency_improvement_pct  12 non-null     float64
#  11  resource_improvement_pct     12 non-null     float64
# dtypes: float64(9), object(3)
# memory usage: 1.3+ KB

# %%
################################################################################################################################################################################

# %%
# Calculate Improvement %
df1['Improvement (%)'] = ((df1['Traditional'] - df1['AI-Augmented']) / df1['Traditional']) * 100

# Round improvement to 2 decimal places
df1['Improvement (%)'] = df1['Improvement (%)'].round(2)

# Display the table
df1
# Out:
#   complexity  Traditional  AI-Augmented  Improvement (%)
# 0        Low         12.3           9.6            21.95
# 1     Medium         22.7          15.2            33.04
# 2       High         31.5          18.9            40.00
# 3   Critical         43.1          25.5            40.84

# %%
# Calculate Improvement %
df3['Improvement (%)'] = ((df3['AI-Augmented'] - df3['Traditional']) / df3['Traditional']) * 100

# Round improvement to 2 decimal places
df3['Improvement (%)'] = df3['Improvement (%)'].round(2)

# Display the table
df3
# Out:
#    mission_sequence  Traditional  AI-Augmented  Improvement (%)
# 0                 1         59.3          83.6            40.98
# 1                 2         61.2          85.1            39.05
# 2                 3         63.5          89.3            40.63
# 3                 4         64.1          90.7            41.50
# 4                 5         65.7          92.2            40.33

# %%
# Calculate Improvement %
df6['Improvement (%)'] = ((df6['AI-Augmented'] - df6['Traditional']) / df6['Traditional']) * 100

# Round improvement to 2 decimal places
df6['Improvement (%)'] = df6['Improvement (%)'].round(2)

# Display the table
df6
# Out:
#      phase  Traditional  AI-Augmented  Improvement (%)
# 0   Launch         83.5          92.7            11.02
# 1  Transit         76.2          89.5            17.45
# 2  Orbital         72.8          91.2            25.27
# 3  Surface         68.7          88.9            29.40
# 4   Return         70.3          90.7            29.02

# %%
# Calculate Improvement %
df9['Improvement (%)'] = ((df9['AI-Augmented'] - df9['Traditional']) / df9['Traditional']) * 100

# Round improvement to 2 decimal places
df9['Improvement (%)'] = df9['Improvement (%)'].round(2)

# Display the table
df9
# Out:
#      resource  Traditional  AI-Augmented  Improvement (%)
# 0       Power         83.2          89.1             7.09
# 1  Propellant         79.5          87.3             9.81
# 2   Bandwidth         84.6          86.2             1.89
# 3   Crew Time         79.4          90.3            13.73

# %%
df5.head(2)
# Out:
#   mission_id        date  mission_type agency complexity  duration_days
# 0       M001  2023-10-27    Deep Space   NASA        Low            120
# 1       M002  2018-11-13  ISS Resupply   NASA        Low             12

# %%
# Grouping by agency and mission_type, and counting the number of missions
mission_counts = df5.groupby(['agency', 'mission_type']).size().unstack(fill_value=0)

mission_counts['Total'] = mission_counts.sum(axis=1)

# Displaying the table
mission_counts = mission_counts.reset_index()
mission_counts ## Count the number of missions for each mission_type by each agency from august 2015 - december 2023
# Out:
# mission_type agency  Deep Space  Earth Orbit  ISS Resupply  Lunar  Mars  Total
# 0               ESA           2            0             3      9     1     15
# 1              JAXA           1            2             4      2     7     16
# 2              NASA           5            5             4      0     2     16

# %%
# Group by 'agency', 'mission_type', and 'complexity' and count
mission_counts_complex = df5.groupby(['agency', 'mission_type', 'complexity']).size().unstack(fill_value=0)

# Define the desired order of complexity levels
complexity_order = ['Low', 'Medium', 'High', 'Critical']

# Reindex the columns based on the desired order
mission_counts_complex = mission_counts_complex.reindex(columns=complexity_order, fill_value=0)

# Display the resulting table with the ordered columns
mission_counts_complex ## the counts of missions for each mission type by each agency, with the complexity levels
# Out:
# complexity           Low  Medium  High  Critical
# agency mission_type
# ESA    Deep Space      1       0     0         1
#        ISS Resupply    0       1     1         1
#        Lunar           2       5     0         2
#        Mars            0       1     0         0
# JAXA   Deep Space      0       0     1         0
#        Earth Orbit     0       0     0         2
#        ISS Resupply    1       0     3         0
#        Lunar           0       1     0         1
#        Mars            2       1     2         2
# NASA   Deep Space      2       0     1         2
#        Earth Orbit     1       0     3         1
#        ISS Resupply    3       1     0         0
#        Mars            0       1     1         0

# %% [markdown]
# **Comparing agencies: esa, jaxa, nasa at complexity: Medium, Mission type: Mars** reason for doing this because only mars mission from all mission type and complexity medium from all complexities in all three agencies

# %%
# Filter the data
filtered_df = df7[
    (df7['agency'] == 'ESA') &
    (df7['complexity'] == 'Medium') &
    (df7['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented
traditional_df = filtered_df[filtered_df['planning_method'] == 'Traditional']
ai_augmented_df = filtered_df[filtered_df['planning_method'] == 'AI-Augmented']

# Create a comparison table
comparison_ESA = pd.DataFrame({
    'Feature': [
        'planning_time_hours',
        'contigency_coverage_pct',
        'resource_efficiency_pct',
        'knowledge_transfer_pct',
        'adaptability_score',
        'quality_assessment'
    ],
    'Traditional': [
        traditional_df['planning_time_hours'].values[0],
        traditional_df['contingency_coverage_pct'].values[0],
        traditional_df['resource_efficiency_pct'].values[0],
        traditional_df['knowledge_transfer_pct'].values[0],
        traditional_df['adaptability_score'].values[0],
        traditional_df['quality_assessment'].values[0]
    ],
    'AI-Augmented': [
        ai_augmented_df['planning_time_hours'].values[0],
        ai_augmented_df['contingency_coverage_pct'].values[0],
        ai_augmented_df['resource_efficiency_pct'].values[0],
        ai_augmented_df['knowledge_transfer_pct'].values[0],
        ai_augmented_df['adaptability_score'].values[0],
        ai_augmented_df['quality_assessment'].values[0]
    ]
})

# Calculate % Improvement correctly
improvements = []
for idx, row in comparison_ESA.iterrows():
    if row['Feature'] == 'planning_time_hours':
        # For planning time: (Traditional - AI) / Traditional * 100
        improvement = (row['Traditional'] - row['AI-Augmented']) / row['Traditional'] * 100
    else:
        # For other features: (AI - Traditional) / Traditional * 100
        improvement = (row['AI-Augmented'] - row['Traditional']) / row['Traditional'] * 100
    improvements.append(improvement)

comparison_ESA['% Improvement'] = improvements

# Print heading
print("Agency: ESA, Complexity: Medium, Mission Type: Mars")

# Display the table
comparison_ESA
# Out:
# Agency: ESA, Complexity: Medium, Mission Type: Mars
#                    Feature  Traditional  AI-Augmented  % Improvement
# 0      planning_time_hours    21.343920     13.392485      37.253867
# 1  contigency_coverage_pct    76.959742     94.551495      22.858384
# 2  resource_efficiency_pct    82.089529     88.919702       8.320395
# 3   knowledge_transfer_pct    57.732943     80.641146      39.679603
# 4       adaptability_score     6.656437      8.241964      23.819461
# 5       quality_assessment     7.350243      7.880467       7.213691

# %%
# Filter the data
filtered_df = df7[
    (df7['agency'] == 'JAXA') &
    (df7['complexity'] == 'Medium') &
    (df7['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented
traditional_df = filtered_df[filtered_df['planning_method'] == 'Traditional']
ai_augmented_df = filtered_df[filtered_df['planning_method'] == 'AI-Augmented']

# Create a comparison table
comparison_JAXA = pd.DataFrame({
    'Feature': [
        'planning_time_hours',
        'contigency_coverage_pct',
        'resource_efficiency_pct',
        'knowledge_transfer_pct',
        'adaptability_score',
        'quality_assessment'
    ],
    'Traditional': [
        traditional_df['planning_time_hours'].values[0],
        traditional_df['contingency_coverage_pct'].values[0],
        traditional_df['resource_efficiency_pct'].values[0],
        traditional_df['knowledge_transfer_pct'].values[0],
        traditional_df['adaptability_score'].values[0],
        traditional_df['quality_assessment'].values[0]
    ],
    'AI-Augmented': [
        ai_augmented_df['planning_time_hours'].values[0],
        ai_augmented_df['contingency_coverage_pct'].values[0],
        ai_augmented_df['resource_efficiency_pct'].values[0],
        ai_augmented_df['knowledge_transfer_pct'].values[0],
        ai_augmented_df['adaptability_score'].values[0],
        ai_augmented_df['quality_assessment'].values[0]
    ]
})

# Calculate % Improvement correctly
improvements = []
for idx, row in comparison_JAXA.iterrows():
    if row['Feature'] == 'planning_time_hours':
        # For planning time: (Traditional - AI) / Traditional * 100
        improvement = (row['Traditional'] - row['AI-Augmented']) / row['Traditional'] * 100
    else:
        # For other features: (AI - Traditional) / Traditional * 100
        improvement = (row['AI-Augmented'] - row['Traditional']) / row['Traditional'] * 100
    improvements.append(improvement)

comparison_JAXA['% Improvement'] = improvements

# Print heading
print("Agency: JAXA, Complexity: Medium, Mission Type: Mars")

# Display the table
comparison_JAXA
# Out:
# Agency: JAXA, Complexity: Medium, Mission Type: Mars
#                    Feature  Traditional  AI-Augmented  % Improvement
# 0      planning_time_hours    21.949105     14.089491      35.808356
# 1  contigency_coverage_pct    71.504169     87.145543      21.874773
# 2  resource_efficiency_pct    83.941307     90.513608       7.829639
# 3   knowledge_transfer_pct    59.808909     83.517425      39.640442
# 4       adaptability_score     7.469914      8.980742      20.225502
# 5       quality_assessment     7.942119      8.545257       7.594167

# %%
# Filter the data
filtered_df = df7[
    (df7['agency'] == 'NASA') &
    (df7['complexity'] == 'Medium') &
    (df7['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented
traditional_df = filtered_df[filtered_df['planning_method'] == 'Traditional']
ai_augmented_df = filtered_df[filtered_df['planning_method'] == 'AI-Augmented']

# Create a comparison table
comparison_NASA = pd.DataFrame({
    'Feature': [
        'planning_time_hours',
        'contigency_coverage_pct',
        'resource_efficiency_pct',
        'knowledge_transfer_pct',
        'adaptability_score',
        'quality_assessment'
    ],
    'Traditional': [
        traditional_df['planning_time_hours'].values[0],
        traditional_df['contingency_coverage_pct'].values[0],
        traditional_df['resource_efficiency_pct'].values[0],
        traditional_df['knowledge_transfer_pct'].values[0],
        traditional_df['adaptability_score'].values[0],
        traditional_df['quality_assessment'].values[0]
    ],
    'AI-Augmented': [
        ai_augmented_df['planning_time_hours'].values[0],
        ai_augmented_df['contingency_coverage_pct'].values[0],
        ai_augmented_df['resource_efficiency_pct'].values[0],
        ai_augmented_df['knowledge_transfer_pct'].values[0],
        ai_augmented_df['adaptability_score'].values[0],
        ai_augmented_df['quality_assessment'].values[0]
    ]
})

# Calculate % Improvement correctly
improvements = []
for idx, row in comparison_NASA.iterrows():
    if row['Feature'] == 'planning_time_hours':
        # For planning time: (Traditional - AI) / Traditional * 100
        improvement = (row['Traditional'] - row['AI-Augmented']) / row['Traditional'] * 100
    else:
        # For other features: (AI - Traditional) / Traditional * 100
        improvement = (row['AI-Augmented'] - row['Traditional']) / row['Traditional'] * 100
    improvements.append(improvement)

comparison_NASA['% Improvement'] = improvements

# Print heading
print("Agency: NASA, Complexity: Medium, Mission Type: Mars")

# Display the table
comparison_NASA
# Out:
# Agency: NASA, Complexity: Medium, Mission Type: Mars
#                    Feature  Traditional  AI-Augmented  % Improvement
# 0      planning_time_hours    21.494314     13.094896      39.077395
# 1  contigency_coverage_pct    79.208724     95.713761      20.837397
# 2  resource_efficiency_pct    78.610780     84.695996       7.740944
# 3   knowledge_transfer_pct    58.768776     82.809401      40.907138
# 4       adaptability_score     7.306201      8.948125      22.473019
# 5       quality_assessment     7.848260      8.327533       6.106741

# %%
# Create a combined table from prebuilt comparison_ESA, comparison_JAXA, comparison_NASA

combined_improvement = pd.DataFrame({
    'Feature': comparison_ESA['Feature'],
    'ESA': comparison_ESA['% Improvement'].round(2),
    'JAXA': comparison_JAXA['% Improvement'].round(2),
    'NASA': comparison_NASA['% Improvement'].round(2)
})

# Display the final table
print("Percentage Improvement Comparison Across Agencies at Complexity: Medium and Mission Type: Mars")
combined_improvement
# Out:
# Percentage Improvement Comparison Across Agencies at Complexity: Medium and Mission Type: Mars
#                    Feature    ESA   JAXA   NASA
# 0      planning_time_hours  37.25  35.81  39.08
# 1  contigency_coverage_pct  22.86  21.87  20.84
# 2  resource_efficiency_pct   8.32   7.83   7.74
# 3   knowledge_transfer_pct  39.68  39.64  40.91
# 4       adaptability_score  23.82  20.23  22.47
# 5       quality_assessment   7.21   7.59   6.11

# %%
# Create a combined table from prebuilt comparison_ESA, comparison_JAXA, comparison_NASA
combined_improvement = pd.DataFrame({
    'Feature': comparison_ESA['Feature'],
    'ESA': comparison_ESA['% Improvement'].round(2),
    'JAXA': comparison_JAXA['% Improvement'].round(2),
    'NASA': comparison_NASA['% Improvement'].round(2)
})

# Set the 'Feature' column as the index for easier plotting
combined_improvement.set_index('Feature', inplace=True)

# Plotting the bar chart
fig, ax = plt.subplots(figsize=(10, 6))
combined_improvement.plot(kind='bar', ax=ax)

# Adding labels and title
ax.set_ylabel('% Improvement (AI vs Traditional)')
ax.set_xlabel('Performance Feature')
ax.set_title('Percentage Improvement of Planning after using AI-Augmented Method (Medium Complexity, Mars Mission)')
ax.legend(title='Agency')
ax.grid(axis='y', linestyle='--')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a combined table from prebuilt comparison_ESA, comparison_JAXA, comparison_NASA

combined_AI_Augmented = pd.DataFrame({
    'Feature': comparison_ESA['Feature'],
    'ESA': comparison_ESA['AI-Augmented'].round(2),
    'JAXA': comparison_JAXA['AI-Augmented'].round(2),
    'NASA': comparison_NASA['AI-Augmented'].round(2)
})

# Display the final table
print("AI-Augmented Method Comparison Across Agencies at Complexity: Medium and Mission Type: Mars")
combined_AI_Augmented
# Out:
# AI-Augmented Method Comparison Across Agencies at Complexity: Medium and Mission Type: Mars
#                    Feature    ESA   JAXA   NASA
# 0      planning_time_hours  13.39  14.09  13.09
# 1  contigency_coverage_pct  94.55  87.15  95.71
# 2  resource_efficiency_pct  88.92  90.51  84.70
# 3   knowledge_transfer_pct  80.64  83.52  82.81
# 4       adaptability_score   8.24   8.98   8.95
# 5       quality_assessment   7.88   8.55   8.33

# %%
combined_AI_Augmented = pd.DataFrame({
    'Feature': comparison_ESA['Feature'],
    'ESA': comparison_ESA['AI-Augmented'].round(2),
    'JAXA': comparison_JAXA['AI-Augmented'].round(2),
    'NASA': comparison_NASA['AI-Augmented'].round(2)
})

# Set the 'Feature' column as the index for easier plotting
combined_AI_Augmented.set_index('Feature', inplace=True)

# Plotting the bar chart
fig, ax = plt.subplots(figsize=(10, 6))
combined_AI_Augmented.plot(kind='bar', ax=ax)

# Adding labels and title
ax.set_ylabel('AI-Augmented Method Value')
ax.set_xlabel('Performance Feature')
ax.set_title('AI-Augmented Method Comparison Across Agencies (Medium Complexity, Mars Mission)')
ax.legend(title='Agency')
ax.grid(axis='y', linestyle='--')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a combined table from prebuilt comparison_ESA, comparison_JAXA, comparison_NASA

combined_traditional = pd.DataFrame({
    'Feature': comparison_ESA['Feature'],
    'ESA': comparison_ESA['Traditional'].round(2),
    'JAXA': comparison_JAXA['Traditional'].round(2),
    'NASA': comparison_NASA['Traditional'].round(2)
})

# Display the final table
print("Traditional Method Comparison Across Agencies at Complexity: Medium and Mission Type: Mars")
combined_traditional
# Out:
# Traditional Method Comparison Across Agencies at Complexity: Medium and Mission Type: Mars
#                    Feature    ESA   JAXA   NASA
# 0      planning_time_hours  21.34  21.95  21.49
# 1  contigency_coverage_pct  76.96  71.50  79.21
# 2  resource_efficiency_pct  82.09  83.94  78.61
# 3   knowledge_transfer_pct  57.73  59.81  58.77
# 4       adaptability_score   6.66   7.47   7.31
# 5       quality_assessment   7.35   7.94   7.85

# %%
# Create a combined table
combined_traditional = pd.DataFrame({
    'Feature': comparison_ESA['Feature'],
    'ESA': comparison_ESA['Traditional'].round(2),
    'JAXA': comparison_JAXA['Traditional'].round(2),
    'NASA': comparison_NASA['Traditional'].round(2)
})

# Set the 'Feature' column as the index for easier plotting
combined_traditional.set_index('Feature', inplace=True)

# Plotting the bar chart
fig, ax = plt.subplots(figsize=(10, 6))
combined_traditional.plot(kind='bar', ax=ax)

# Adding labels and title
ax.set_ylabel('Traditional Method Value')
ax.set_xlabel('Performance Feature')
ax.set_title('Traditional Method Comparison Across Agencies (Medium Complexity, Mars Mission)')
ax.legend(title='Agency')
ax.grid(axis='y', linestyle='--')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **Use following table final for Comparing agencies: esa, jaxa, nasa at complexity: Medium, Mission type: Mars.**

# %%
#### USE THIS FINAL
# Merge the two tables side-by-side on 'Feature'
combined_final = pd.DataFrame({
    'Feature': comparison_ESA['Feature'],
    'ESA_Trad': comparison_ESA['Traditional'].round(2),
    'JAXA_Trad': comparison_JAXA['Traditional'].round(2),
    'NASA_Trad': comparison_NASA['Traditional'].round(2),
    'ESA_%improvement': comparison_ESA['% Improvement'].round(2),
    'JAXA_%improvement': comparison_JAXA['% Improvement'].round(2),
    'NASA_%improvement': comparison_NASA['% Improvement'].round(2)
})

# Display the final merged table
print("Traditional Values and % Improvement Using AI-Augmented Method Across Agencies at Complexity: Medium and Mission Type: Mars")
display(combined_final)
# Out:
# Traditional Values and % Improvement Using AI-Augmented Method Across Agencies at Complexity: Medium and Mission Type: Mars
#                    Feature  ESA_Trad  JAXA_Trad  NASA_Trad  ESA_%improvement  \
# 0      planning_time_hours     21.34      21.95      21.49             37.25
# 1  contigency_coverage_pct     76.96      71.50      79.21             22.86
# 2  resource_efficiency_pct     82.09      83.94      78.61              8.32
# 3   knowledge_transfer_pct     57.73      59.81      58.77             39.68
# 4       adaptability_score      6.66       7.47       7.31             23.82
# 5       quality_assessment      7.35       7.94       7.85              7.21
#
#    JAXA_%improvement  NASA_%improvement
# 0              35.81              39.08
# 1              21.87              20.84
# 2               7.83               7.74
# 3              39.64              40.91
# 4              20.23              22.47
# 5               7.59               6.11

# %% [markdown]
# **Use this table final as another example to get approximation understanding that ai_augmented improved performance or not**

# %%
#### merged df4 and df5

# %%
# Merge df4 and df5 on 'mission_id'
merged_df4_df5 = pd.merge(df4, df5, on='mission_id', how='inner')

# Display the merged dataset
print("Merged Data: mission_phase_data + missions_data")
display(merged_df4_df5.head())
# Out:
# Merged Data: mission_phase_data + missions_data
#   mission_id    phase planning_method  planning_time_hours  \
# 0       M001   Launch     Traditional            12.859352
# 1       M001   Launch    AI-Augmented             8.210370
# 2       M001  Transit     Traditional             6.589434
# 3       M001  Transit    AI-Augmented             4.120904
# 4       M001  Orbital     Traditional             6.148368
#
#    contingency_coverage_pct        date mission_type agency complexity  \
# 0                 77.659540  2023-10-27   Deep Space   NASA        Low
# 1                 93.772477  2023-10-27   Deep Space   NASA        Low
# 2                 69.833292  2023-10-27   Deep Space   NASA        Low
# 3                 84.477082  2023-10-27   Deep Space   NASA        Low
# 4                 69.491161  2023-10-27   Deep Space   NASA        Low
#
#    duration_days
# 0            120
# 1            120
# 2            120
# 3            120
# 4            120

# %%
# Filter based on the given conditions
filtered_phase_data = merged_df4_df5[
    (merged_df4_df5['agency'] == 'ESA') &
    (merged_df4_df5['complexity'] == 'Medium') &
    (merged_df4_df5['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'Traditional'][['phase', 'planning_time_hours']]
ai_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'AI-Augmented'][['phase', 'planning_time_hours']]

# Merge Traditional and AI-Augmented side by side on phase
comparison_phase_ESA = pd.merge(traditional_phase, ai_phase, on='phase', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_phase_ESA['planning_time_%Improvement'] = ((comparison_phase_ESA['planning_time_hours_Traditional'] - comparison_phase_ESA['planning_time_hours_AI']) / comparison_phase_ESA['planning_time_hours_Traditional']) * 100
comparison_phase_ESA['planning_time_%Improvement'] = comparison_phase_ESA['planning_time_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: ESA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement")
display(comparison_phase_ESA)
# Out:
# Agency: ESA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement
#      phase  planning_time_hours_Traditional  planning_time_hours_AI  \
# 0   Launch                        14.628551                9.191414
# 1  Transit                         9.309369                5.926611
# 2  Orbital                         5.311831                3.345146
# 3  Surface                        14.945494                9.217068
# 4   Return                         6.672581                4.246493
#
#    planning_time_%Improvement
# 0                       37.17
# 1                       36.34
# 2                       37.02
# 3                       38.33
# 4                       36.36

# %%
# Filter based on the given conditions
filtered_phase_data = merged_df4_df5[
    (merged_df4_df5['agency'] == 'ESA') &
    (merged_df4_df5['complexity'] == 'Medium') &
    (merged_df4_df5['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'Traditional'][['phase', 'contingency_coverage_pct']]
ai_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'AI-Augmented'][['phase', 'contingency_coverage_pct']]

# Merge Traditional and AI-Augmented side by side on phase
comparison_phase_ESA1 = pd.merge(traditional_phase, ai_phase, on='phase', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_phase_ESA1['contingency_coverage_%Improvement'] = ((comparison_phase_ESA1['contingency_coverage_pct_AI'] - comparison_phase_ESA1['contingency_coverage_pct_Traditional']) / comparison_phase_ESA1['contingency_coverage_pct_Traditional']) * 100
comparison_phase_ESA1['contingency_coverage_%Improvement'] = comparison_phase_ESA1['contingency_coverage_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: ESA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement")
display(comparison_phase_ESA1)
# Out:
# Agency: ESA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement
#      phase  contingency_coverage_pct_Traditional  contingency_coverage_pct_AI  \
# 0   Launch                             78.036678                    95.129989
# 1  Transit                             79.549765                    96.143656
# 2  Orbital                             63.220753                    75.994951
# 3  Surface                             65.396328                    80.492187
# 4   Return                             59.852480                    73.009231
#
#    contingency_coverage_%Improvement
# 0                              21.90
# 1                              20.86
# 2                              20.21
# 3                              23.08
# 4                              21.98

# %%
# Filter based on the given conditions
filtered_phase_data = merged_df4_df5[
    (merged_df4_df5['agency'] == 'JAXA') &
    (merged_df4_df5['complexity'] == 'Medium') &
    (merged_df4_df5['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'Traditional'][['phase', 'planning_time_hours']]
ai_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'AI-Augmented'][['phase', 'planning_time_hours']]

# Merge Traditional and AI-Augmented side by side on phase
comparison_phase_JAXA = pd.merge(traditional_phase, ai_phase, on='phase', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_phase_JAXA['planning_time_%Improvement'] = ((comparison_phase_JAXA['planning_time_hours_Traditional'] - comparison_phase_JAXA['planning_time_hours_AI']) / comparison_phase_JAXA['planning_time_hours_Traditional']) * 100
comparison_phase_JAXA['planning_time_%Improvement'] = comparison_phase_JAXA['planning_time_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: JAXA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement")
display(comparison_phase_JAXA)
# Out:
# Agency: JAXA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement
#      phase  planning_time_hours_Traditional  planning_time_hours_AI  \
# 0   Launch                        10.709923                6.747262
# 1  Transit                         9.559855                6.108676
# 2  Orbital                         9.805069                6.001705
# 3  Surface                         9.637433                6.080332
# 4   Return                        11.656136                7.183945
#
#    planning_time_%Improvement
# 0                       37.00
# 1                       36.10
# 2                       38.79
# 3                       36.91
# 4                       38.37

# %%
# Filter based on the given conditions
filtered_phase_data = merged_df4_df5[
    (merged_df4_df5['agency'] == 'JAXA') &
    (merged_df4_df5['complexity'] == 'Medium') &
    (merged_df4_df5['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'Traditional'][['phase', 'contingency_coverage_pct']]
ai_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'AI-Augmented'][['phase', 'contingency_coverage_pct']]

# Merge Traditional and AI-Augmented side by side on phase
comparison_phase_JAXA1 = pd.merge(traditional_phase, ai_phase, on='phase', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_phase_JAXA1['contingency_coverage_%Improvement'] = ((comparison_phase_JAXA1['contingency_coverage_pct_AI'] - comparison_phase_JAXA1['contingency_coverage_pct_Traditional']) / comparison_phase_JAXA1['contingency_coverage_pct_Traditional']) * 100
comparison_phase_JAXA1['contingency_coverage_%Improvement'] = comparison_phase_JAXA1['contingency_coverage_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: JAXA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement")
display(comparison_phase_JAXA1)
# Out:
# Agency: JAXA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement
#      phase  contingency_coverage_pct_Traditional  contingency_coverage_pct_AI  \
# 0   Launch                             82.058654                    99.427723
# 1  Transit                             78.092326                    93.834548
# 2  Orbital                             60.388743                    74.849824
# 3  Surface                             63.731099                    78.268073
# 4   Return                             58.675875                    71.626138
#
#    contingency_coverage_%Improvement
# 0                              21.17
# 1                              20.16
# 2                              23.95
# 3                              22.81
# 4                              22.07

# %%
# Filter based on the given conditions
filtered_phase_data = merged_df4_df5[
    (merged_df4_df5['agency'] == 'NASA') &
    (merged_df4_df5['complexity'] == 'Medium') &
    (merged_df4_df5['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'Traditional'][['phase', 'planning_time_hours']]
ai_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'AI-Augmented'][['phase', 'planning_time_hours']]

# Merge Traditional and AI-Augmented side by side on phase
comparison_phase_NASA = pd.merge(traditional_phase, ai_phase, on='phase', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_phase_NASA['planning_time_%Improvement'] = ((comparison_phase_NASA['planning_time_hours_Traditional'] - comparison_phase_NASA['planning_time_hours_AI']) / comparison_phase_NASA['planning_time_hours_Traditional']) * 100
comparison_phase_NASA['planning_time_%Improvement'] = comparison_phase_NASA['planning_time_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: NASA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement")
display(comparison_phase_NASA)
# Out:
# Agency: NASA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement
#      phase  planning_time_hours_Traditional  planning_time_hours_AI  \
# 0   Launch                         8.470095                5.196297
# 1  Transit                         8.249356                4.965842
# 2  Orbital                         9.521990                5.863716
# 3  Surface                         8.123593                5.274905
# 4   Return                         5.554340                3.510098
#
#    planning_time_%Improvement
# 0                       38.65
# 1                       39.80
# 2                       38.42
# 3                       35.07
# 4                       36.80

# %%
# Filter based on the given conditions
filtered_phase_data = merged_df4_df5[
    (merged_df4_df5['agency'] == 'NASA') &
    (merged_df4_df5['complexity'] == 'Medium') &
    (merged_df4_df5['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'Traditional'][['phase', 'contingency_coverage_pct']]
ai_phase = filtered_phase_data[filtered_phase_data['planning_method'] == 'AI-Augmented'][['phase', 'contingency_coverage_pct']]

# Merge Traditional and AI-Augmented side by side on phase
comparison_phase_NASA1 = pd.merge(traditional_phase, ai_phase, on='phase', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_phase_NASA1['contingency_coverage_%Improvement'] = ((comparison_phase_NASA1['contingency_coverage_pct_AI'] - comparison_phase_NASA1['contingency_coverage_pct_Traditional']) / comparison_phase_NASA1['contingency_coverage_pct_Traditional']) * 100
comparison_phase_NASA1['contingency_coverage_%Improvement'] = comparison_phase_NASA1['contingency_coverage_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: NASA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement")
display(comparison_phase_NASA1)
# Out:
# Agency: NASA | Complexity: Medium | Mission Type: Mars | Phase-wise Traditional vs AI vs % Improvement
#      phase  contingency_coverage_pct_Traditional  contingency_coverage_pct_AI  \
# 0   Launch                             73.962232                    88.923569
# 1  Transit                             79.545508                    95.843142
# 2  Orbital                             75.309750                    91.899689
# 3  Surface                             57.771834                    71.556468
# 4   Return                             75.632612                    93.384852
#
#    contingency_coverage_%Improvement
# 0                              20.23
# 1                              20.49
# 2                              22.03
# 3                              23.86
# 4                              23.47

# %% [markdown]
# **All agency comparison | complexity: Medium | Mission Type: Mars | Feature: Planning time | All phases**

# %%
# Merge the two tables side-by-side on 'Feature'
combined_ESA_JAXA_NASA = pd.DataFrame({
    'phase': comparison_phase_ESA['phase'],
    'ESA_Trad': comparison_phase_ESA['planning_time_hours_Traditional'],
    'JAXA_Trad': comparison_phase_JAXA['planning_time_hours_Traditional'],
    'NASA_Trad': comparison_phase_NASA['planning_time_hours_Traditional'],
    'ESA_%improvement': comparison_phase_ESA['planning_time_%Improvement'],
    'JAXA_%improvement': comparison_phase_JAXA['planning_time_%Improvement'],
    'NASA_%improvement': comparison_phase_NASA['planning_time_%Improvement']
})

# Display the final merged table
print("All agencies | Mars Missions | Planning Time Feature | Comparison of Traditional and % Improvement using AI-Augmented Method")
display(combined_ESA_JAXA_NASA)
# Out:
# All agencies | Mars Missions | Planning Time Feature | Comparison of Traditional and % Improvement using AI-Augmented Method
#      phase   ESA_Trad  JAXA_Trad  NASA_Trad  ESA_%improvement  \
# 0   Launch  14.628551  10.709923   8.470095             37.17
# 1  Transit   9.309369   9.559855   8.249356             36.34
# 2  Orbital   5.311831   9.805069   9.521990             37.02
# 3  Surface  14.945494   9.637433   8.123593             38.33
# 4   Return   6.672581  11.656136   5.554340             36.36
#
#    JAXA_%improvement  NASA_%improvement
# 0              37.00              38.65
# 1              36.10              39.80
# 2              38.79              38.42
# 3              36.91              35.07
# 4              38.37              36.80

# %% [markdown]
# **All agency comparison | complexity: Medium | Mission Type: Mars | Feature: Contingency Coverage | All phases**

# %%
# Merge the two tables side-by-side on 'Feature'
combined_ESA1_JAXA1_NASA1 = pd.DataFrame({
    'phase': comparison_phase_ESA1['phase'],
    'ESA_Trad': comparison_phase_ESA1['contingency_coverage_pct_Traditional'],
    'JAXA_Trad': comparison_phase_JAXA1['contingency_coverage_pct_Traditional'],
    'NASA_Trad': comparison_phase_NASA1['contingency_coverage_pct_Traditional'],
    'ESA_%improvement': comparison_phase_ESA1['contingency_coverage_%Improvement'],
    'JAXA_%improvement': comparison_phase_JAXA1['contingency_coverage_%Improvement'],
    'NASA_%improvement': comparison_phase_NASA1['contingency_coverage_%Improvement']
})

# Display the final merged table
print("All agencies | Mars Missions | Contingency Coverage Feature | Comparison of Traditional and % Improvement using AI-Augmented Method")
display(combined_ESA1_JAXA1_NASA1)
# Out:
# All agencies | Mars Missions | Contingency Coverage Feature | Comparison of Traditional and % Improvement using AI-Augmented Method
#      phase   ESA_Trad  JAXA_Trad  NASA_Trad  ESA_%improvement  \
# 0   Launch  78.036678  82.058654  73.962232             21.90
# 1  Transit  79.549765  78.092326  79.545508             20.86
# 2  Orbital  63.220753  60.388743  75.309750             20.21
# 3  Surface  65.396328  63.731099  57.771834             23.08
# 4   Return  59.852480  58.675875  75.632612             21.98
#
#    JAXA_%improvement  NASA_%improvement
# 0              21.17              20.23
# 1              20.16              20.49
# 2              23.95              22.03
# 3              22.81              23.86
# 4              22.07              23.47

# %%
## merge df5 and df8

# %%
# Merge df4 and df5 on 'mission_id'
merged_df5_df8 = pd.merge(df5, df8, on='mission_id', how='inner')

# Display the merged dataset
print("Merged Data: mission_phase_data + missions_data")
display(merged_df5_df8.head(1))
# Out:
# Merged Data: mission_phase_data + missions_data
#   mission_id        date mission_type agency complexity  duration_days  \
# 0       M001  2023-10-27   Deep Space   NASA        Low            120
#
#   resource planning_method  efficiency_pct
# 0    Power     Traditional       82.442038

# %%
# Filter based on the given conditions
filtered_resource_data = merged_df5_df8[
    (merged_df5_df8['agency'] == 'ESA') &
    (merged_df5_df8['complexity'] == 'Medium') &
    (merged_df5_df8['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_resource = filtered_resource_data[filtered_resource_data['planning_method'] == 'Traditional'][['resource', 'efficiency_pct']]
ai_resource = filtered_resource_data[filtered_resource_data['planning_method'] == 'AI-Augmented'][['resource', 'efficiency_pct']]

# Merge Traditional and AI-Augmented side by side on 	resource
comparison_resource_ESA = pd.merge(traditional_resource, ai_resource, on='resource', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_resource_ESA['efficiency_%Improvement'] = ((comparison_resource_ESA['efficiency_pct_AI'] - comparison_resource_ESA['efficiency_pct_Traditional']) / comparison_resource_ESA['efficiency_pct_Traditional']) * 100
comparison_resource_ESA['efficiency_%Improvement'] = comparison_resource_ESA['efficiency_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: ESA | Complexity: Medium | Mission Type: Mars | resource-wise Traditional vs AI vs % Improvement")
display(comparison_resource_ESA)
# Out:
# Agency: ESA | Complexity: Medium | Mission Type: Mars | resource-wise Traditional vs AI vs % Improvement
#      resource  efficiency_pct_Traditional  efficiency_pct_AI  \
# 0       Power                   79.129684          85.148491
# 1  Propellant                   73.749569          79.443237
# 2   Bandwidth                   75.876427          82.609638
# 3   Crew Time                   76.511121          82.334420
#
#    efficiency_%Improvement
# 0                     7.61
# 1                     7.72
# 2                     8.87
# 3                     7.61

# %%
# Filter based on the given conditions
filtered_resource_data = merged_df5_df8[
    (merged_df5_df8['agency'] == 'JAXA') &
    (merged_df5_df8['complexity'] == 'Medium') &
    (merged_df5_df8['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_resource = filtered_resource_data[filtered_resource_data['planning_method'] == 'Traditional'][['resource', 'efficiency_pct']]
ai_resource = filtered_resource_data[filtered_resource_data['planning_method'] == 'AI-Augmented'][['resource', 'efficiency_pct']]

# Merge Traditional and AI-Augmented side by side on 	resource
comparison_resource_JAXA = pd.merge(traditional_resource, ai_resource, on='resource', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_resource_JAXA['efficiency_%Improvement'] = ((comparison_resource_JAXA['efficiency_pct_AI'] - comparison_resource_JAXA['efficiency_pct_Traditional']) / comparison_resource_JAXA['efficiency_pct_Traditional']) * 100
comparison_resource_JAXA['efficiency_%Improvement'] = comparison_resource_JAXA['efficiency_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: JAXA | Complexity: Medium | Mission Type: Mars | resource-wise Traditional vs AI vs % Improvement")
display(comparison_resource_JAXA)
# Out:
# Agency: JAXA | Complexity: Medium | Mission Type: Mars | resource-wise Traditional vs AI vs % Improvement
#      resource  efficiency_pct_Traditional  efficiency_pct_AI  \
# 0       Power                   85.435032          92.464513
# 1  Propellant                   71.883194          77.660314
# 2   Bandwidth                   76.501690          82.985107
# 3   Crew Time                   76.116108          82.479762
#
#    efficiency_%Improvement
# 0                     8.23
# 1                     8.04
# 2                     8.47
# 3                     8.36

# %%
# Filter based on the given conditions
filtered_resource_data = merged_df5_df8[
    (merged_df5_df8['agency'] == 'NASA') &
    (merged_df5_df8['complexity'] == 'Medium') &
    (merged_df5_df8['mission_type'] == 'Mars')
]

# Separate Traditional and AI-Augmented methods
traditional_resource = filtered_resource_data[filtered_resource_data['planning_method'] == 'Traditional'][['resource', 'efficiency_pct']]
ai_resource = filtered_resource_data[filtered_resource_data['planning_method'] == 'AI-Augmented'][['resource', 'efficiency_pct']]

# Merge Traditional and AI-Augmented side by side on 	resource
comparison_resource_NASA = pd.merge(traditional_resource, ai_resource, on='resource', suffixes=('_Traditional', '_AI'))

# Calculate % Improvement
comparison_resource_NASA['efficiency_%Improvement'] = ((comparison_resource_NASA['efficiency_pct_AI'] - comparison_resource_NASA['efficiency_pct_Traditional']) / comparison_resource_NASA['efficiency_pct_Traditional']) * 100
comparison_resource_NASA['efficiency_%Improvement'] = comparison_resource_NASA['efficiency_%Improvement'].round(2)  # Round for clean view

# Display the final table
print("Agency: NASA | Complexity: Medium | Mission Type: Mars | resource-wise Traditional vs AI vs % Improvement")
display(comparison_resource_NASA)
# Out:
# Agency: NASA | Complexity: Medium | Mission Type: Mars | resource-wise Traditional vs AI vs % Improvement
#      resource  efficiency_pct_Traditional  efficiency_pct_AI  \
# 0       Power                   81.752021          88.808769
# 1  Propellant                   79.433015          86.338150
# 2   Bandwidth                   84.189265          90.507234
# 3   Crew Time                   78.422898          84.634838
#
#    efficiency_%Improvement
# 0                     8.63
# 1                     8.69
# 2                     7.50
# 3                     7.92

# %% [markdown]
# **All agency comparison | complexity: Medium | Mission Type: Mars | Feature: resources**

# %%
# Merge the two tables side-by-side on 'Feature'
combinedd_ESA_JAXA_NASA = pd.DataFrame({
    'resource': comparison_resource_ESA['resource'],
    'ESA_Trad': comparison_resource_ESA['efficiency_pct_Traditional'],
    'JAXA_Trad': comparison_resource_JAXA['efficiency_pct_Traditional'],
    'NASA_Trad': comparison_resource_NASA['efficiency_pct_Traditional'],
    'ESA_%improvement': comparison_resource_ESA['efficiency_%Improvement'],
    'JAXA_%improvement': comparison_resource_JAXA['efficiency_%Improvement'],
    'NASA_%improvement': comparison_resource_NASA['efficiency_%Improvement']
})

# Display the final merged table
print("All agencies | Mars Missions | resource Feature | Comparison of Traditional and % Improvement using AI-Augmented Method")
display(combinedd_ESA_JAXA_NASA)
# Out:
# All agencies | Mars Missions | resource Feature | Comparison of Traditional and % Improvement using AI-Augmented Method
#      resource   ESA_Trad  JAXA_Trad  NASA_Trad  ESA_%improvement  \
# 0       Power  79.129684  85.435032  81.752021              7.61
# 1  Propellant  73.749569  71.883194  79.433015              7.72
# 2   Bandwidth  75.876427  76.501690  84.189265              8.87
# 3   Crew Time  76.511121  76.116108  78.422898              7.61
#
#    JAXA_%improvement  NASA_%improvement
# 0               8.23               8.63
# 1               8.04               8.69
# 2               8.47               7.50
# 3               8.36               7.92

# %% [markdown]
# **Time Trend — AI Only (Three Separate Graphs)**

# %%
# Make sure 'date' is datetime type
df7['date'] = pd.to_datetime(df7['date'])

# Extract year
df7['year'] = df7['date'].dt.year

# Filter for years 2015-2023 and AI-Augmented only
df7_ai_only = df7[
    (df7['year'] >= 2015) & (df7['year'] <= 2023) &
    (df7['planning_method'] == 'AI-Augmented')
]

# Group by year and calculate mean
ai_trend_summary = df7_ai_only.groupby('year').agg({
    'planning_time_hours': 'mean',
    'quality_assessment': 'mean',
    'knowledge_transfer_pct': 'mean',
    'contingency_coverage_pct': 'mean',
    'resource_efficiency_pct': 'mean',
    'adaptability_score': 'mean'
}).round(2).reset_index()

# --- Plot 1: Planning Time Hours ---
plt.figure(figsize=(10,6))
sns.lineplot(
    data=ai_trend_summary,
    x='year',
    y='planning_time_hours',
    marker='o',
    color='royalblue'
)
plt.title('AI-Augmented: Planning Time Hours Trend (2015-2023)')
plt.ylabel('Planning Time (Hours)')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# --- Plot 2: Quality Assessment ---
plt.figure(figsize=(10,6))
sns.lineplot(
    data=ai_trend_summary,
    x='year',
    y='quality_assessment',
    marker='o',
    color='seagreen'
)
plt.title('AI-Augmented: Quality Assessment Trend (2015-2023)')
plt.ylabel('Quality Assessment Score')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# --- Plot 3: Knowledge Transfer Percentage ---
plt.figure(figsize=(10,6))
sns.lineplot(
    data=ai_trend_summary,
    x='year',
    y='knowledge_transfer_pct',
    marker='o',
    color='darkorange'
)
plt.title('AI-Augmented: Knowledge Transfer Percentage Trend (2015-2023)')
plt.ylabel('Knowledge Transfer (%)')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# --- Plot 4: Contingency Coverage Percentage ---
plt.figure(figsize=(10,6))
sns.lineplot(
    data=ai_trend_summary,
    x='year',
    y='contingency_coverage_pct',
    marker='o',
    color='pink'
)
plt.title('AI-Augmented: contingency coverage Percentage Trend (2015-2023)')
plt.ylabel('contingency coverage (%)')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# --- Plot 5: Resource Efficiency Percentage ---
plt.figure(figsize=(10,6))
sns.lineplot(
    data=ai_trend_summary,
    x='year',
    y='resource_efficiency_pct',
    marker='o',
    color='Black'
)
plt.title('AI-Augmented: Resource Efficiency Percentage Trend (2015-2023)')
plt.ylabel('Resource Efficiency (%)')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# --- Plot 6: adaptability_score Percentage ---
plt.figure(figsize=(10,6))
sns.lineplot(
    data=ai_trend_summary,
    x='year',
    y='adaptability_score',
    marker='o',
    color='brown'
)
plt.title('AI-Augmented: Adaptability Score Percentage Trend (2015-2023)')
plt.ylabel('Adaptability Score')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# %%
df7.head(1)
# Out:
#   mission_id planning_method  planning_time_hours  contingency_coverage_pct  \
# 0       M001     Traditional             14.45401                 76.100519
#
#    resource_efficiency_pct  knowledge_transfer_pct  adaptability_score  \
# 0                81.279352               62.271078            7.818015
#
#    quality_assessment       date mission_type agency complexity  \
# 0            8.160731 2023-10-27   Deep Space   NASA        Low
#
#    duration_days  year
# 0            120  2023

# %% [markdown]
# # **df10**

# %%
# First, melt the dataframe to long format for easier plotting
df_melted = pd.melt(
    df10,
    id_vars=['scenario_type', 'complexity'],
    value_vars=[
        'trad_planning_time', 'ai_planning_time',
        'trad_contingency_coverage', 'ai_contingency_coverage',
        'trad_resource_efficiency', 'ai_resource_efficiency'
    ],
    var_name='Metric',
    value_name='Value'
)

# Extract method (Traditional or AI) and Feature from 'Metric' column
df_melted['Method'] = df_melted['Metric'].apply(lambda x: 'Traditional' if 'trad' in x else 'AI-Augmented')
df_melted['Feature'] = df_melted['Metric'].apply(
    lambda x: 'Planning Time' if 'planning_time' in x else
              'Contingency Coverage' if 'contingency_coverage' in x else
              'Resource Efficiency'
)

# Set plot style
sns.set(style="whitegrid")

# Create a plot for each feature
features = ['Planning Time', 'Contingency Coverage', 'Resource Efficiency']

for feature in features:
    plt.figure(figsize=(14, 6))
    feature_data = df_melted[df_melted['Feature'] == feature]

    sns.barplot(
        data=feature_data,
        x='scenario_type',
        y='Value',
        hue='Method',
        ci=None
    )

    plt.title(f'{feature} Comparison (Traditional vs AI) by Scenario Type', fontsize=16)
    plt.xlabel('Scenario Type', fontsize=14)
    plt.ylabel(f'{feature} Value', fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.legend(title='Method')
    plt.tight_layout()
    plt.show()

# Optional: You can do the same split by "complexity" too
for feature in features:
    plt.figure(figsize=(14, 6))
    feature_data = df_melted[df_melted['Feature'] == feature]

    sns.barplot(
        data=feature_data,
        x='complexity',
        y='Value',
        hue='Method',
        ci=None
    )

    plt.title(f'{feature} Comparison (Traditional vs AI) by Complexity Level', fontsize=16)
    plt.xlabel('Complexity Level', fontsize=14)
    plt.ylabel(f'{feature} Value', fontsize=14)
    plt.legend(title='Method')
    plt.tight_layout()
    plt.show()

# %%
####################### Expert Analysis ##########################################

# %%
# 1. Group by 'role' and calculate averages
role_based_avg = df2.groupby('role')[['traditional_rating', 'ai_rating', 'perceived_improvement_pct']].mean().reset_index()

print("Average Ratings and Improvement Percentage per Role:")
role_based_avg
# Out:
# Average Ratings and Improvement Percentage per Role:
#                            role  traditional_rating  ai_rating  \
# 0       Flight Dynamics Officer            7.840115   8.327195
# 1              Mission Director            7.479806   7.943894
# 2  Resource Planning Specialist            7.483222   7.928168
# 3      Risk Assessment Engineer            7.953604   8.513627
# 4    Science Operations Planner            7.515508   7.992816
#
#    perceived_improvement_pct
# 0                   6.200815
# 1                   6.186136
# 2                   5.941121
# 3                   7.050956
# 4                   6.306312

# %%
# 2. Find role with highest perceived improvement
most_improvement_role = role_based_avg.loc[role_based_avg['perceived_improvement_pct'].idxmax(), 'role']
print(f"\nRole perceiving the most improvement from AI: {most_improvement_role}")

# 2a. Find role with least perceived improvement
least_improvement_role = role_based_avg.loc[role_based_avg['perceived_improvement_pct'].idxmin(), 'role']
print(f"\nRole perceiving the least improvement from AI: {least_improvement_role}")
# Out:
# Role perceiving the most improvement from AI: Risk Assessment Engineer
#
# Role perceiving the least improvement from AI: Resource Planning Specialist

# %%
import pandas as pd

# Assuming df2 is already loaded

# 1. Group by 'agency' and calculate averages
agency_based_avg = df2.groupby('agency')[['traditional_rating', 'ai_rating', 'perceived_improvement_pct']].mean().reset_index()

print("Average Ratings and Improvement Percentage per Agency:")
agency_based_avg
# Out:
# Average Ratings and Improvement Percentage per Agency:
#   agency  traditional_rating  ai_rating  perceived_improvement_pct
# 0    ESA            7.554373   8.019229                   6.143511
# 1   JAXA            7.660335   8.177047                   6.737883
# 2   NASA            7.671108   8.132691                   5.984483

# %%
# 2. Find agency whose experts feel the biggest improvement
most_improvement_agency = agency_based_avg.loc[agency_based_avg['perceived_improvement_pct'].idxmax(), 'agency']
print(f"\nAgency whose experts feel the biggest improvement with AI: {most_improvement_agency}")
# Out:
# Agency whose experts feel the biggest improvement with AI: JAXA

# %%
# 1. Group by 'experience' and calculate averages
experience_based_avg = df2.groupby('experience')[['traditional_rating', 'ai_rating', 'perceived_improvement_pct']].mean().reset_index()

print("Average Ratings and Improvement Percentage per Experience Level:")
experience_based_avg
# Out:
# Average Ratings and Improvement Percentage per Experience Level:
#     experience  traditional_rating  ai_rating  perceived_improvement_pct
# 0  10-15 years            7.538619   7.999583                   6.095842
# 1    15+ years            7.861660   8.383350                   6.608883
# 2   5-10 years            7.523945   7.978677                   6.051055

# %%
# 2. Find which experience group rates AI highest
highest_ai_rating_experience = experience_based_avg.loc[experience_based_avg['ai_rating'].idxmax(), 'experience']
print(f"\nExperience group rating AI the highest: {highest_ai_rating_experience}")

# 3. Find which experience group perceives the biggest improvement
highest_improvement_experience = experience_based_avg.loc[experience_based_avg['perceived_improvement_pct'].idxmax(), 'experience']
print(f"Experience group perceiving the most improvement with AI: {highest_improvement_experience}")
# Out:
# Experience group rating AI the highest: 15+ years
# Experience group perceiving the most improvement with AI: 15+ years
